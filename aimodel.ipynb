# %%
import csv
import pandas as pd

def read_csv_to_dataframe(file_path):
    """
    Reads a CSV file and returns its contents as a pandas DataFrame.
    
    Args:
        file_path (str): The path to the CSV file.
        
    Returns:
        pd.DataFrame: DataFrame containing the CSV data.
    """
    try:
        df = pd.read_csv(file_path)
        return df
    except Exception as e:
        print(f"Error reading CSV file: {e}")
        return None

data = read_csv_to_dataframe('10000jobs_candidates/resume_job_matching_dataset.csv')

# %%
data
# Out:
#                                         job_description  \
# 0     Data Analyst needed with experience in SQL, Ex...
# 1     Data Scientist needed with experience in Stati...
# 2     Software Engineer needed with experience in Sy...
# 3     ML Engineer needed with experience in Python, ...
# 4     Software Engineer needed with experience in RE...
# ...                                                 ...
# 9995  Product Manager needed with experience in Scru...
# 9996  Data Analyst needed with experience in Tableau...
# 9997  Product Manager needed with experience in Prod...
# 9998  Product Manager needed with experience in Agil...
# 9999  Data Scientist needed with experience in NLP, ...
#
#                                                  resume  match_score
# 0     Experienced professional skilled in SQL, Power...            4
# 1     Experienced professional skilled in Python, De...            4
# 2     Experienced professional skilled in wait, Git,...            5
# 3     Experienced professional skilled in return, De...            4
# 4     Experienced professional skilled in REST APIs,...            5
# ...                                                 ...          ...
# 9995  Experienced professional skilled in commercial...            4
# 9996  Experienced professional skilled in financial,...            2
# 9997  Experienced professional skilled in internatio...            2
# 9998  Experienced professional skilled in role, Agil...            2
# 9999  Experienced professional skilled in Machine Le...            3
#
# [10000 rows x 3 columns]
